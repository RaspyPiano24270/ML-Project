# %%
import sys
import os


# Add the 'src' folder to Python's path so we can import our own scripts
module_path = os.path.abspath(os.path.join('..', 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)

from data_loader import load_kaggle_csv
print("Setup Complete. SRC folder is now accessible.")
# Out:
# Setup Complete. SRC folder is now accessible.

# %%
import os
import sys
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model

os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin'

# --- 2. Load and Plot ---
model_path = '../models/lstm_regressor.h5'

try:
    model = load_model(model_path)
    
    # Generate the standard schematic 


    plot_model(
        model, 
        to_file='model_architecture_schematic.png', 
        show_shapes=True, 
        show_layer_names=True,
        dpi=96
    )
    print("Success! Saved 'model_architecture_schematic.png'")
    
    # Display
    from IPython.display import Image
    display(Image('model_architecture_schematic.png'))

except Exception as e:
    print(f"Still failing? Try Netron.app instead!\nError: {e}")
# Out:
#   Cell In[14], line 19
#     [Image of LSTM neural network architecture]
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %% [markdown]
# # I'm getting a failure will check it out later
