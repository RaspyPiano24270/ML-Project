# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Adjust the CSV path below depending on where your dataset is saved inside the `data/` folder.
# This notebook allows you to quickly inspect column names, basic statistics, missing values, and distributions.

# %%
import sys
import os

# Add the 'src' folder to Python's path so we can import our own scripts
module_path = os.path.abspath(os.path.join('..', 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)

from data_loader import load_kaggle_csv
print("Setup Complete. SRC folder is now accessible.")
# Out:
# Setup Complete. SRC folder is now accessible.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = load_kaggle_csv('../data/rain_prediction_dataset.csv')
df.head()
# Out:
# Loading data from: ../data/rain_prediction_dataset.csv
# Filtering data for location: New York
# Final dataset shape: (3655, 7)
#             Temperature   Humidity  Wind Speed  Precipitation  Cloud Cover  \
# Date
# 2024-01-01    87.524795  75.655455   28.379506       0.000000    69.617966
# 2024-01-01    37.385581  58.266978    0.406152       0.280896    66.057494
# 2024-01-01    96.288813  73.781542   23.257037       0.190299    83.871577
# 2024-01-01    41.080995  40.880140   15.078712       0.000000    53.538718
# 2024-01-01    31.855688  46.717335   27.882836       0.691770    47.778458
#
#                Pressure  Rain Tomorrow
# Date
# 2024-01-01  1026.030278              0
# 2024-01-01  1013.127575              0
# 2024-01-01  1018.783003              0
# 2024-01-01  1027.471786              0
# 2024-01-01   991.799861              0

# %%
# Shape (rows, columns)
df.shape
# Out:
# (3655, 7)

# %%
# Column names
df.columns.tolist()
# Out:
# ['Temperature',
#  'Humidity',
#  'Wind Speed',
#  'Precipitation',
#  'Cloud Cover',
#  'Pressure',
#  'Rain Tomorrow']

# %%
# Summary statistics
df.describe(include='all')
# Out:
#        Temperature     Humidity   Wind Speed  Precipitation  Cloud Cover  \
# count  3655.000000  3655.000000  3655.000000    3655.000000  3655.000000
# mean     65.076588    59.875347    14.860518       0.377238    54.918539
# std      20.098835    23.318708     8.742128       0.466541    25.755364
# min      30.011057    20.046339     0.012273       0.000000    10.024329
# 25%      47.701114    39.705594     7.070208       0.000000    33.198520
# 50%      64.770491    59.911103    14.778235       0.189012    54.392695
# 75%      82.436535    79.807745    22.599314       0.642605    76.797213
# max      99.974820    99.970892    29.995994       2.631709    99.923008
#
#           Pressure  Rain Tomorrow
# count  3655.000000    3655.000000
# mean   1005.609997       0.208482
# std      20.237997       0.406278
# min     970.002299       0.000000
# 25%     988.305852       0.000000
# 50%    1006.046910       0.000000
# 75%    1023.325557       0.000000
# ...

# %%
# Check missing values
df.isnull().sum()
# Out:
# Temperature      0
# Humidity         0
# Wind Speed       0
# Precipitation    0
# Cloud Cover      0
# Pressure         0
# Rain Tomorrow    0
# dtype: int64

# %%
# Plot distributions for all numeric features
df.hist(figsize=(12, 12))
plt.tight_layout()
plt.show()
