# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Adjust the CSV path below depending on where your dataset is saved inside the `data/` folder.
# This notebook allows you to quickly inspect column names, basic statistics, missing values, and distributions.

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_path = r'C:\Users\Alvaro\OneDrive\Documents\Custom Office Templates\Desktop\Github\Fall_Projects\ML-Project\data\usa_rain_prediction_dataset.csv'

df = pd.read_csv(csv_path)
df.head()
# Out:
#          Date  Location  Temperature   Humidity  Wind Speed  Precipitation  \
# 0  2024-01-01  New York    87.524795  75.655455   28.379506       0.000000
# 1  2024-01-02  New York    83.259325  28.712617   12.436433       0.526995
# 2  2024-01-03  New York    80.943050  64.740043   14.184831       0.916884
# 3  2024-01-04  New York    78.097552  59.738984   19.444029       0.094134
# 4  2024-01-05  New York    37.059963  34.766784    3.689661       1.361272
#
#    Cloud Cover     Pressure  Rain Tomorrow
# 0    69.617966  1026.030278              0
# 1    41.606048   995.962065              0
# 2    77.364763   980.796739              1
# 3    52.541196   979.012163              0
# 4    85.584000  1031.790859              0

# %%
# Shape (rows, columns)
df.shape
# Out:
# (73100, 9)

# %%
# Column names
df.columns.tolist()
# Out:
# ['Date',
#  'Location',
#  'Temperature',
#  'Humidity',
#  'Wind Speed',
#  'Precipitation',
#  'Cloud Cover',
#  'Pressure',
#  'Rain Tomorrow']

# %%
# Summary statistics
df.describe(include='all')
# Out:
#               Date  Location   Temperature      Humidity    Wind Speed  \
# count        73100     73100  73100.000000  73100.000000  73100.000000
# unique         731        20           NaN           NaN           NaN
# top     2024-01-01  New York           NaN           NaN           NaN
# freq           100      3655           NaN           NaN           NaN
# mean           NaN       NaN     65.182270     59.875041     15.017946
# std            NaN       NaN     20.205793     23.066115      8.668729
# min            NaN       NaN     30.000766     20.000272      0.000712
# 25%            NaN       NaN     47.678968     39.800732      7.485182
# 50%            NaN       NaN     65.294949     59.887840     15.102495
# 75%            NaN       NaN     82.636570     79.835990     22.551794
# max            NaN       NaN     99.997393     99.999025     29.999017
#
#         Precipitation   Cloud Cover      Pressure  Rain Tomorrow
# ...

# %%
# Check missing values
df.isnull().sum()
# Out:
# Date             0
# Location         0
# Temperature      0
# Humidity         0
# Wind Speed       0
# Precipitation    0
# Cloud Cover      0
# Pressure         0
# Rain Tomorrow    0
# dtype: int64

# %%
# Plot distributions for all numeric features
df.hist(figsize=(12, 12))
plt.tight_layout()
plt.show()
